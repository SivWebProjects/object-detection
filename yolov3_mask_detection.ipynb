# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/yolo_custom_model_training'
# Out:
# backup	custom_dataset	custom_dataset.zip  custom_weight  darknet

# %%
Unzipping the folder

# %%
#!unzip '/content/drive/MyDrive/yolo_custom_model_training/custom_dataset.zip' -d '/content/drive/MyDrive/yolo_custom_model_training/'

# %%
#!git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolo_custom_model_training/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolo_custom_model_training/darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.02 MiB | 5.75 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_training/darknet
# Out:
# /content/drive/MyDrive/yolo_custom_model_training/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
#!make
# Out:
# chmod +x *.sh

# %%
running make file

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make

# %%
change darknet folder path to root folder

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_training
# Out:
# /content/drive/MyDrive/yolo_custom_model_training

# %%
# !python custom_dataset/creating-files-data-and-name.py

# %%
# !python custom_dataset/creating-train-and-test-txt-files.py

# %%
# !ls
# Out:
# backup	custom_dataset	custom_dataset.zip  custom_weight  darknet

# %%
# !darknet/darknet detector train custom_dataset/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.774802), count: 2, class_loss = 1.247774, iou_loss = 0.305265, total_loss = 1.553039
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.709058), count: 1, class_loss = 0.851845, iou_loss = 0.357272, total_loss = 1.209118
#  total_bbox = 108335, rewritten_bbox = 0.001846 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000231, iou_loss = 0.000000, total_loss = 0.000231
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.006775, iou_loss = 0.000000, total_loss = 0.006775
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.812246), count: 2, class_loss = 1.869854, iou_loss = 0.542933, total_loss = 2.412787
# ...
